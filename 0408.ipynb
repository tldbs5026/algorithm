# %% [markdown]
# 카카오 2020_1 아이디 추천

# %%
import re
id = "...!@BaT#*..y.abcdefghijklm" 	


# new_id의 모든 대문자를 대응되는 소문자로 치환

new_id = id.lower()

# 2단계 new_id에서 알파벳 소문자, 숫자, 빼기(-), 밑줄(_), 마침표(.)를 제외한 모든 문자를 제거합니다. 
new_id = re.sub(r'[^a-z0-9\_\-\.]', '', new_id)

# 3단계 new_id에서 마침표(.)가 2번 이상 연속된 부분을 하나의 마침표(.)로 치환합니다. 
new_id = re.sub(r'[\.]+', '.', new_id)
# 4단계 new_id에서 마침표(.)가 처음이나 끝에 위치한다면 제거합니다.
if new_id.startswith('.') :
  new_id = new_id[1:] 

if new_id.endswith('.') :
  new_id = new_id[:-1]
# 5단계 new_id가 빈 문자열이라면, new_id에 "a"를 대입합니다.
if len(new_id) == 0 :
  new_id = 'a' 
# 6단계 new_id의 길이가 16자 이상이면, new_id의 첫 15개의 문자를 제외한 나머지 문자들을 모두 제거합니다. 
#   만약 제거 후 마침표(.)가 new_id의 끝에 위치한다면 끝에 위치한 마침표(.) 문자를 제거합니다. 
if len(new_id) >= 16 :
  new_id = new_id[:15]
  if new_id[-1] == '.' :
    new_id = new_id[:-1]
# 7단계 new_id의 길이가 2자 이하라면, new_id의 마지막 문자를 new_id의 길이가 3이 될 때까지 반복해서 끝에 붙입니다.

while len(new_id) <= 2 :
  new_id += new_id[-1]

# %% [markdown]
# 카카오 2020_2 문자열 압축

# %%
def solution(s) :
  answer = []


  sent = len(s)

  for cut in range(2, sent/2) :
    now_idx = cut
    bef = s[:cut]
    cnt =1
    tmp = ''

  
  while now_idx + cut <= sent :
    if bef == s[now_idx : now_idx + cut] :
      cnt +=1
    
    else :
      if cnt > 1 :
        tmp += str(cnt)
        tmp += bef
        cnt =1
        bef = s[now_idx : now_idx + cut]

    
    now_idx += cut
  
  if cnt  >1 :
    tmp += str(cnt)
  
  tmp += s[now_idx-cut :]
  answer = min(answer, sent)

  return answer

# %%
# 1. 입력이 빈 문자열인 경우, 빈 문자열을 반환합니다.

# 2. 문자열 w를 두 "균형잡힌 괄호 문자열" u, v로 분리합니다. 
# 단, u는 "균형잡힌 괄호 문자열"로 더 이상 분리할 수 없어야 하며, v는 빈 문자열이 될 수 있습니다.

# 3. 문자열 u가 "올바른 괄호 문자열" 이라면 문자열 v에 대해 1단계부터 다시 수행합니다.

def recursive(p) :
  if len(p) == 0 :
    return 
  
  left, right = 0,0

  for idx in range(len(p)) :
    if p[idx] == '(' :
      left +=1
    
    else :
      right +=1
    
    if left == right :
      u = p[:idx+1]
      v = p[idx+1:]
      break
    
    if right_p(u) :
      return u + recursive(v)
    else :
      tmp = '('
      tmp += recursive(v)
      tmp += ')'
      u = u[1:-1]

      for letter in u :
        if letter == ')' :
          tmp += '('
        else :
          tmp += ')'
      return tmp

# 수행한 결과 문자열을 u에 이어 붙인 후 반환합니다.
#  문자열 u가 "올바른 괄호 문자열"이 아니라면 아래 과정을 수행합니다.
# 4-1. 빈 문자열에 첫 번째 문자로 '('를 붙입니다.
# 4-2. 문자열 v에 대해 1단계부터 재귀적으로 수행한 결과 문자열을 이어 붙입니다.
# 4-3. ')'를 다시 붙입니다.
# 4-4. u의 첫 번째와 마지막 문자를 제거하고, 나머지 문자열의 괄호 방향을 뒤집어서 뒤에 붙입니다.
# 4-5. 생성된 문자열을 반환합니다.

def right_p(u) :
  cnt = 0
  
  for letter in u :
    if letter == '(' :
      cnt +=1
    else :
      cnt -=1
    
  
    if cnt <0 :
      return False
  
  if cnt == 0 :
    return True
  else :
    return False

def solution(p) :
  answer = recursive(p)
  return answer

# %%
def solution(n,s,a,b, fares) :
  inf = 1e-9

  answer =inf

  graph = [[inf] for _ in range(n)] 

  for i in range(n) :
    for j in range(n) :
      if i == j :
        graph [i][j] = 0

  
  for f in fares :
    node1, node2, fee = f


    graph[node1 - 1][node2 - 1] = fee
    graph[node2 - 1][node1 - 1] = fee

  
  #floyd warshall algorithm

  for k in range(n) :
    for i in range(n) :
      for j in range(n) :
        graph[i][j] = min(graph[i][j], graph[i][k]+graph[k][j])

  
  for t in range(n) :
    tmp = graph[s-1][t] + graph[t][a-1] + graph[t][b-1]
    answer = min(tmp, answer)

  return answer

# %%
def rotate(key) :
  new_key = [[0 for y in range(len(key))] for x in range(len(key))]

  for x in range(len(key)) :
    for y in range(len(key)) :
      new_key[x][y] = key[y][abs(x-(len(key))-1)]
  return new_key

#key 와 lock 확인

def is_correct_key(key, M, lock2, N, x,y) :
  field = [[0 for y in range(n*3)] for x in range(n*3)]

  for i in range(N,N+N) :
    for j in range(N, N+N) : 
      field[i][j] = lock2[i][j]

  
  for i in range(x, x+M) :
    for j in range(y, y+M) :
      field[i][j] += key[i-x][i-y]

  #lock 안이 전부 1이라면 T,  아니면 F

  for i in range(N, N+N) :
    for j in range(N, N+N) :
      if field[i][j] != 1 :
        return False
  
  return True

def solution(key, lock) :
  answer = False
  M,N = len(key),len(lock)

  #new lock 생성

  lock2 = [[0 for _ in range(n+3)] for _ in range(n+3)]

  for x in range(n, n+n) :
    for y in range(n, n+n) :
      lock2[x][y] = lock[x-n][y-n]

  # rotate

  for k in range(4) :
    key = rotate(key)

    # key의 x,y 범위 지정

    for x in range(n-m+1, n+n) :
      for y in range(n-m+1, n+n) :
        is_correct = is_correct_key(key, m, lock2,n,x,y)

        if is_correct == True :
          answer = True
        
  return answer

# %%
def add(head, word) :

  node = head

  for w in word :
    if w not in node :
      node[w] = {}

    node = node[w]

    if 'len' not in node :
      node['len'] = [len_word]
    else :
      node['len'].append(len_word)

  

  for word in words :
    len_word = len(word)
    add(head,word)
    add(head_rev, word[::-1])
    wc.append(len_word)

  
  def search(head,querie) :
    cnt =0
    node = head

    for q in querie :
      if q == '?' :
        return node['len'].count(len_qu)

      elif q not in node :
        break 
      
      node = node[q]
    return cnt
  
  li  =[]

  for querie in queries :
    len_qu = len(querie)

    if querie[0] == '?' :
      if querie[-1] == '?' :
        li.append(wc.count(len_qu))
      else :
        li.append(search(head_rev, querie[::-1]))
    else :
      li.append(search(head, querie))
  
  return li

# %% [markdown]
# 2021 - 순위검색

# %% [markdown]
# 2020-경주로 건설
#
# https://school.programmers.co.kr/learn/courses/30/lessons/67259

# %% [markdown]
# 2020- 자물쇠와 열쇠
#
# https://school.programmers.co.kr/learn/courses/30/lessons/60059

# %% [markdown]
# 2021 - 표 편집
#
# https://school.programmers.co.kr/learn/courses/30/lessons/81303

# %% [markdown]
# 2020 - 기둥과 보 설치
#
# https://school.programmers.co.kr/learn/courses/30/lessons/60061
